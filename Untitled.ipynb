# %% [markdown]
# #Présentation

# %%
# Load the dataset
from data import load_data_viz_data
import pandas as pd
import matplotlib.pyplot as plt

data = load_data_viz_data()
data[['LAT','LONG']] = data[['LAT','LONG']].astype('float64')

print("Shape of the DataFrame:", data.shape)

data.head(10)
# Out:
# Shape of the DataFrame: (237221, 9)
#   INCIDENT_NUMBER        OFFENSE_CODE_GROUP  SHOOTING     OCCURRED_ON_DATE  \
# 0      I192068249                     Other         0  2015-08-28 10:20:00
# 1      I182074094   Violence and harassment         0  2015-09-14 09:31:00
# 2      I182054888   Violence and harassment         0  2015-07-12 15:37:00
# 3      I182054888                     Other         0  2015-07-12 15:37:00
# 4      I182054888                     Other         0  2015-07-12 15:37:00
# 5      I172075854  Fraud and law violations         0  2015-09-02 09:00:00
# 6      I172065681  Fraud and law violations         0  2015-07-25 02:00:00
# 7      I172060902  Fraud and law violations         0  2015-11-12 12:00:00
# 8      I172026505  Fraud and law violations         0  2015-08-01 12:00:00
# 9      I172014289                     Other         0  2015-12-01 12:00:00
#
#          LAT       LONG     NAME  LAT_POLICE_STATION  LONG_POLICE_STATION
# ...

# %%
df_most_common = pd.DataFrame([],columns = ['DISTRICT','MOST_COMMON_INCIDENT'])
i=0
for dis in data['NAME'].unique():
    df = data[data['NAME'] == dis]
    rank = 0 #most common
    off = df[['NAME','OFFENSE_CODE_GROUP']].value_counts().index[rank][1]
    df_most_common.loc[i] = [dis,off]
    i=i+1
df_most_common
# Out:
#          DISTRICT            MOST_COMMON_INCIDENT
# 0         Roxbury           Larceny and vandalism
# 1      Dorchester           Larceny and vandalism
# 2        Downtown           Larceny and vandalism
# 3       Hyde Park           Larceny and vandalism
# 4       South End           Larceny and vandalism
# 5        Mattapan  Police investigation procedure
# 6        Brighton           Larceny and vandalism
# 7     East Boston           Larceny and vandalism
# 8    West Roxbury           Larceny and vandalism
# 9    South Boston           Larceny and vandalism
# 10  Jamaica Plain           Larceny and vandalism
# 11    Charlestown           Larceny and vandalism

# %%
#df_most_common2 = df_most_common
#df_most_common2['MOST_COMMON_INCIDENT'].replace('Larceny and vandalism',1, inplace=True) #Replace NaN by "NoAlley"
#df_most_common2['MOST_COMMON_INCIDENT'].replace('Police investigation procedure',2, inplace=True) #Replace NaN by "NoAlley"

# %%
df_most_common.plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_37739/1845249356.py in <module>
# ----> 1 df_most_common.plot(kind="bar")
#
# ~/.pyenv/versions/lewagon/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/.pyenv/versions/lewagon/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
plt.rcParams["figure.figsize"] = (10, 5)
df_most_common.plot(kind="bar")
plt.xticks(df_most_common['MOST_COMMON_INCIDENT'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_37739/3527170892.py in <module>
#       1 plt.rcParams["figure.figsize"] = (10, 5)
# ----> 2 df_most_common.plot(kind="bar")
#       3 plt.xticks(df_most_common['MOST_COMMON_INCIDENT'])
#
# ~/.pyenv/versions/lewagon/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/.pyenv/versions/lewagon/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
# ...

# %%
df_most_common
# Out:
#          DISTRICT  MOST_COMMON_INCIDENT
# 0         Roxbury                     1
# 1      Dorchester                     1
# 2        Downtown                     1
# 3       Hyde Park                     1
# 4       South End                     1
# 5        Mattapan                     2
# 6        Brighton                     1
# 7     East Boston                     1
# 8    West Roxbury                     1
# 9    South Boston                     1
# 10  Jamaica Plain                     1
# 11    Charlestown                     1

# %%
df_second_common = pd.DataFrame([],columns = ['DISTRICT','SECOND_COMMON_INCIDENT'])
i=0
for dis in data['NAME'].unique():
    df = data[data['NAME'] == dis]
    rank = 1 #most common
    off = df[['NAME','OFFENSE_CODE_GROUP']].value_counts().index[rank][1]
    df_second_common.loc[i] = [dis,off]
    i=i+1
df_second_common
# Out:
#          DISTRICT          SECOND_COMMON_INCIDENT
# 0         Roxbury  Police investigation procedure
# 1      Dorchester  Police investigation procedure
# 2        Downtown  Police investigation procedure
# 3       Hyde Park  Police investigation procedure
# 4       South End  Police investigation procedure
# 5        Mattapan           Larceny and vandalism
# 6        Brighton  Police investigation procedure
# 7     East Boston  Police investigation procedure
# 8    West Roxbury  Police investigation procedure
# 9    South Boston  Police investigation procedure
# 10  Jamaica Plain  Police investigation procedure
# 11    Charlestown  Police investigation procedure

# %%
df_second_common['SECOND_COMMON_INCIDENT'].replace('Larceny and vandalism',1, inplace=True) #Replace NaN by "NoAlley"
df_second_common['SECOND_COMMON_INCIDENT'].replace('Police investigation procedure',2, inplace=True) #Replace NaN by "NoAlley"

# %%
df_second_common
# Out:
#          DISTRICT  SECOND_COMMON_INCIDENT
# 0         Roxbury                       2
# 1      Dorchester                       2
# 2        Downtown                       2
# 3       Hyde Park                       2
# 4       South End                       2
# 5        Mattapan                       1
# 6        Brighton                       2
# 7     East Boston                       2
# 8    West Roxbury                       2
# 9    South Boston                       2
# 10  Jamaica Plain                       2
# 11    Charlestown                       2

# %%
plt.rcParams["figure.figsize"] = (10, 5)
df_second_common.plot(kind="bar")
# Out:
# <AxesSubplot:>
